# %%
import torch
import sys
import os

print("Python :", sys.version[:6])
print("PyTorch:", torch.__version__)
print("GPU    :", torch.cuda.is_available())
if torch.cuda.is_available():
    print("GPU name:", torch.cuda.get_device_name(0))
# Out:
# Python : 3.12.1
# PyTorch: 2.10.0+cu128
# GPU    : True
# GPU name: Tesla T4

# %%
# %pip install -q nuscenes-devkit==1.1.11 pyquaternion einops timm tqdm
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.0/61.0 kB 5.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 316.0/316.0 kB 28.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.0/18.0 MB 77.8 MB/s eta 0:00:00:00:0100:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.0/50.0 MB 17.1 MB/s eta 0:00:00:00:0100:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.5/2.5 MB 76.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 115.9/115.9 kB 14.3 MB/s eta 0:00:00
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# shap 0.51.0 requires numpy>=2, but you have numpy 1.26.4 which is incompatible.
# jaxlib 0.7.2 requires numpy>=2.0, but you have numpy 1.26.4 which is incompatible.
# jax 0.7.2 requires numpy>=2.0, but you have numpy 1.26.4 which is incompatible.
# ...

# %%
import numpy
print("numpy:", numpy.__version__)  # should be 1.26.4

from nuscenes.nuscenes import NuScenes
import torch
print("nuscenes OK ✓")
print("torch  :", torch.__version__)
print("GPU    :", torch.cuda.is_available())
# Out:
# numpy: 1.26.4
# nuscenes OK ✓
# torch  : 2.10.0+cu128
# GPU    : True

# %%
import os
print(os.getcwd())
print(os.path.exists('/Users/nirajmac/Downloads/HACKATHON'))
# Out:
# /content
# False

# %%
# !git clone https://github.com/nirajj12/Bird-s-Eye-View-BEV-2D-Occupancy.git
# %cd Bird-s-Eye-View-BEV-2D-Occupancy

import sys
import os
sys.path.insert(0, '/content/Bird-s-Eye-View-BEV-2D-Occupancy')
print("Files:", os.listdir('.'))
# Out:
# fatal: destination path 'Bird-s-Eye-View-BEV-2D-Occupancy' already exists and is not an empty directory.
# /content/Bird-s-Eye-View-BEV-2D-Occupancy
# Files: ['train.py', 'logger', 'data', '.git', 'Bird-s-Eye-View-BEV-2D-Occupancy', 'config', 'requirements.txt', '.gitignore', 'eval.py', 'utils', 'models', 'exception', 'results']

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# ---------------------------------------------------------------------------
# MessageError                              Traceback (most recent call last)
# /tmp/ipykernel_10097/1408506528.py in <cell line: 0>()
#       1 from google.colab import drive
# ----> 2 drive.mount('/content/drive')
#
# /usr/local/lib/python3.12/dist-packages/google/colab/drive.py in mount(mountpoint, force_remount, timeout_ms, readonly)
#      95 def mount(mountpoint, force_remount=False, timeout_ms=120000, readonly=False):
#      96   """Mount your Google Drive at the specified mountpoint path."""
# ---> 97   return _mount(
#      98       mountpoint,
#      99       force_remount=force_remount,
#
# /usr/local/lib/python3.12/dist-packages/google/colab/drive.py in _mount(mountpoint, force_remount, timeout_ms, ephemeral, readonly)
#     132   )
#     133   if ephemeral:
# --> 134     _message.blocking_request(
#     135         'request_auth',
#     136         request={'authType': 'dfs_ephemeral'},
#
# ...
